# %%
import pandas as pd
import glob
from pathlib import Path
import numpy as np
from numpy.random import default_rng
rng = default_rng()


folder = "../../results_all/app_history_vm/"
filePrefix = "../../results_all/app_bootstrap_vm/app_bootstrap_vm"
print(folder)

start = 0.05
end = 0.2

numberOfSamples = 10000
CIsmall = 1
# Out:
# ../../results_all/app_history_vm/

# %%
def resample(perfRuntimes1: pd.DataFrame,
            perfRuntimes2: pd.DataFrame,
            instanceRuns: np.ndarray,
            samples: int,
            numberOfSamples: int) -> np.ndarray:
    """
        Resamples performances using hierarchical bootstrapping for building confindence intervals

        Builds a tensor of random indices of a form numberOfSamples * instanceRunsNumber * suiteRunsNumber * numberOfIterations.
        Then uses these indices to choose from a performance runtimes tensor with a form instanceRunsNumber * suiteRunsNumber * numberOfIterations.
        Finally, reshapes resulting tensor to a matrix of form numberOfSamples * ( instanceRunsNumber * suiteRunsNumber * numberOfIterations)
        and calculates performance differences between medians.

        Parameters
        ----------
        perfRuntimes1 : performance runtimes of the first version.
        perfRuntimes2 : performance runtimes of the second version.
        instanceRuns : array of instanceRun numbers
        samples : number of drawn alues

        Returns
        -------
        np.ndarray
            array of performance differences with a shape numberOfSample * 1.

        """
    instanceRunsNumber = instanceRuns.shape[0]

    allRuntimes1 = np.ndarray((instanceRunsNumber, samples))
    allRuntimes2 = np.ndarray((instanceRunsNumber, samples))


    for instanceRun in instanceRuns:
        allRuntimes1[instanceRun - 1]= perfRuntimes1.loc[(perfRuntimes1['run'] == instanceRun),
                                                'latency (ms)'].to_numpy()
        allRuntimes2[instanceRun - 1]= perfRuntimes2.loc[(perfRuntimes2['run'] == instanceRun),
                                                'latency (ms)'].to_numpy()

    medians = []
    for i in range(numberOfSamples):
        #if (i % 1000 == 0):
        #    print(f"i is {i}")
        #Generate Random Arrays
        currentInstanceRun = rng.choice(instanceRuns, size=(instanceRunsNumber)) - 1
        currentRuntimes1 = rng.integers(samples, size=(samples, instanceRunsNumber))
        currentRuntimes2 = rng.integers(samples, size=(samples, instanceRunsNumber))
        #Bulk selection
        tmp1 = allRuntimes1[currentInstanceRun, currentRuntimes1]
        tmp1 = tmp1.reshape((instanceRunsNumber * samples))

        tmp2 = allRuntimes2[currentInstanceRun, currentRuntimes2]
        tmp2 = tmp2.reshape((instanceRunsNumber * samples))

        # Get median for both lists
        med1 = np.median(tmp1, axis=0)
        med2 = np.median(tmp2, axis=0)
        medians.append(med2/med1)

    return medians

def bootstrap(perfRuntimes1: pd.DataFrame,
            perfRuntimes2: pd.DataFrame):

    instanceRuns = perfRuntimes1.run.unique()
    numberOfInstanceRuns = len(instanceRuns)
    print(f"    Found {numberOfInstanceRuns} runs")
    R = resample(perfRuntimes1=perfRuntimes1,
                 perfRuntimes2=perfRuntimes2,
                 instanceRuns=instanceRuns,
                 samples=int(len(perfRuntimes1) / numberOfInstanceRuns),
                 numberOfSamples=numberOfSamples)

    print(f"    Bootstrapping done ({len(R)} elements in R).")

    # Find conf. intervals
    R.sort()

    small = int((numberOfSamples * CIsmall) / 100 / 2)
    if small == 0:
        small  = 1

    minSmall = R[small-1]
    minSmall = (minSmall - 1) * 100
    maxSmall = R[numberOfSamples-small-1]
    maxSmall = (maxSmall - 1) * 100
    return minSmall, maxSmall


all_runs = glob.glob(folder + "*")

for fullRunFolder in all_runs:
    runFolder = fullRunFolder + "/"
    all_numbers = glob.glob(runFolder + "*")
    for fullNumberFolder in all_numbers:

        all_files = glob.glob(fullNumberFolder + "/*")
        size = len(all_files)

        if size != 22:
            print(f"{size} elements in folder {fullNumberFolder}, skip.")
        else:
            tmp = fullNumberFolder.split("\\")

            #Parse run and commit number from path structure
            run = tmp[len(tmp)-2]
            run=run[3:]
            commitNumber = tmp[len(tmp)-1]
            print(f"Check Run {run} Number {commitNumber}")

            filename = Path(filePrefix + "_" + commitNumber + ".csv")
            skip = False

            if filename.is_file():
                print("  Already aggregated, skip")
            else:
                print("  Aggregating...")
                rows = []
                for i in range(3):
                    currFolder = folder + "run" + str((i+1)) + "/" + str(commitNumber)
                    tmp = glob.glob(currFolder + "/*")
                    noOfFiles = len(tmp)
                    print(f"    Current folder: {currFolder} with {noOfFiles} files")

                    if noOfFiles != 22:
                        print(f"ERROR: {noOfFiles} elements in folder {currFolder}, skip.")
                        skip = True
                    else:

                        #Read latency file for both types (old and new)
                        inserts1Old = pd.read_csv(currFolder + "/latenciesInserts1Old.csv",
                                         header=None,
                                         delim_whitespace=True,
                                         names=["batch","latency (ms)"])
                        inserts1Old.sort_values(by=["batch"], inplace=True)
                        number = len(inserts1Old.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        inserts1Old = inserts1Old.iloc[removeFirst:-removeLast , :]

                        for index, row in inserts1Old.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["batch"],
                                "type" : "inserts",
                                "version" : "base",
                                "latency (ms)" : row["latency (ms)"]
                            })

                        inserts1New = pd.read_csv(currFolder + "/latenciesInserts1New.csv",
                                         header=None,
                                         delim_whitespace=True,
                                         names=["batch","latency (ms)"])
                        inserts1New.sort_values(by=["batch"], inplace=True)
                        number = len(inserts1New.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        inserts1New = inserts1New.iloc[removeFirst:-removeLast , :]

                        for index, row in inserts1New.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["batch"],
                                "type" : "inserts",
                                "version" : "variation",
                                "latency (ms)" : row["latency (ms)"]
                            })

                        #Read latency file for both types (old and new)
                        inserts2Old = pd.read_csv(currFolder + "/latenciesInserts2Old.csv",
                                         header=None,
                                         delim_whitespace=True,
                                         names=["batch","latency (ms)"])
                        inserts2Old.sort_values(by=["batch"], inplace=True)
                        number = len(inserts2Old.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        inserts2Old = inserts2Old.iloc[removeFirst:-removeLast , :]

                        for index, row in inserts2Old.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["batch"],
                                "type" : "inserts",
                                "version" : "base",
                                "latency (ms)" : row["latency (ms)"]
                            })

                        inserts2New = pd.read_csv(currFolder + "/latenciesInserts2New.csv",
                                         header=None,
                                         delim_whitespace=True,
                                         names=["batch","latency (ms)"])
                        inserts2New.sort_values(by=["batch"], inplace=True)
                        number = len(inserts2New.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        inserts2New = inserts2New.iloc[removeFirst:-removeLast , :]

                        for index, row in inserts2New.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["batch"],
                                "type" : "inserts",
                                "version" : "variation",
                                "latency (ms)" : row["latency (ms)"]
                            })

                        queries1Old = pd.read_csv(currFolder + "/latenciesQueries1Old.csv",
                                         header=None,
                                         delim_whitespace=True,
                                         names=["query","latency (ms)"])
                        queries1Old.sort_values(by=["query"], inplace=True)
                        number = len(queries1Old.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        queries1Old = queries1Old.iloc[removeFirst:-removeLast , :]


                        for index, row in queries1Old.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["query"],
                                "type" : "simple queries",
                                "version" : "base",
                                "latency (ms)" : row["latency (ms)"]
                            })

                        queries2Old = pd.read_csv(currFolder + "/latenciesQueries2Old.csv",
                                         header=None,
                                         delim_whitespace=True,
                                         names=["query","latency (ms)"])
                        queries2Old.sort_values(by=["query"], inplace=True)

                        number = len(queries2Old.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        queries2Old = queries2Old.iloc[removeFirst:-removeLast , :]

                        for index, row in queries2Old.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["query"],
                                "type" : "group-by queries",
                                "version" : "base",
                                "latency (ms)" : row["latency (ms)"]
                            })

                        queries1New = pd.read_csv(currFolder + "/latenciesQueries1New.csv",
                                         header=None,
                                         delim_whitespace=True,
                                         names=["query","latency (ms)"])
                        queries1New.sort_values(by=["query"], inplace=True)

                        number = len(queries1New.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        queries1New = queries1New.iloc[removeFirst:-removeLast , :]

                        for index, row in queries1New.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["query"],
                                "type" : "simple queries",
                                "version" : "variation",
                                "latency (ms)" : row["latency (ms)"]
                            })

                        queries2New = pd.read_csv(currFolder + "/latenciesQueries2New.csv",
                                         header=None,
                                         delim_whitespace=True,
                                         names=["query","latency (ms)"])
                        queries2New.sort_values(by=["query"], inplace=True)

                        number = len(queries2New.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        queries2New = queries2New.iloc[removeFirst:-removeLast , :]

                        for index, row in queries2New.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["query"],
                                "type" : "group-by queries",
                                "version" : "variation",
                                "latency (ms)" : row["latency (ms)"]
                            })
                if not skip:

                    #Run bootstrapping for each type
                    result = []
                    df_latencies = pd.DataFrame(rows)
                    for type in df_latencies.type.unique():
                        print(f"  Running bootstrapping for type {type}...")

                        benchmarkMeasurements = df_latencies.loc[(df_latencies['type'].str.startswith(type, na=False))]
                        perfRuntimes1 = benchmarkMeasurements.loc[(benchmarkMeasurements['version'] == "base")]
                        perfRuntimes2 = benchmarkMeasurements.loc[(benchmarkMeasurements['version'] == "variation")]

                        print(f"  Find median perf change for type {type}...")
                        median1 = perfRuntimes1["latency (ms)"].median()
                        median2 = perfRuntimes2["latency (ms)"].median()
                        diff = ((median2 / median1) - 1) * 100

                        print(f"  Running bootstrapping for type {type}...")
                        instanceRuns = benchmarkMeasurements.run.unique()
                        numberOfInstanceRuns = len(instanceRuns)
                        min, max = bootstrap(perfRuntimes1, perfRuntimes2)
                        print(f"    Min: {min} Max: {max} (Width: {max-min})")
                        result.append({
                            "commit":commitNumber,
                            "type": type,
                            "min" : min,
                            "med" : diff,
                            "max" : max
                        })

                    # Convert to data frame
                    df_result = pd.DataFrame(result)
                    # Save to file
                    df_result.to_csv(str(filename))
# Out:
# Check Run 1 Number 1
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/1 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/1 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/1 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.5677039226128167 Max: 1.9646954813379747 (Width: 2.5323994039507913)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.08567302504857155 Max: 1.694792456635219 (Width: 1.7804654816837906)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.2572794418342017 Max: 1.281332004878477 (Width: 1.5386114467126788)
# Check Run 1 Number 10
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/10 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/10 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/10 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.157525658353688 Max: 0.19601884301263528 (Width: 3.3535445013663234)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.4741831396498095 Max: 7.796521470334006 (Width: 9.270704609983815)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.449890810220435 Max: -1.3901495767915995 (Width: 2.0597412334288356)
# Check Run 1 Number 11
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/11 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/11 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/11 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.5581435289165677 Max: 0.8960050455241841 (Width: 3.454148574440752)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.4366250485253436 Max: -1.8548334481931938 (Width: 1.5817916003321497)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.7377126578095434 Max: -0.732256240318585 (Width: 2.0054564174909584)
# Check Run 1 Number 12
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/12 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/12 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/12 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.07214241595296933 Max: 3.165546542969455 (Width: 3.093404127016486)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.6933185669230095 Max: -2.2380202583741737 (Width: 1.4552983085488358)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.1468352628179375 Max: -1.7877447834316995 (Width: 1.359090479386238)
# Check Run 1 Number 13
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/13 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/13 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/13 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.8805637245535753 Max: 2.4094952399974945 (Width: 5.29005896455107)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -4.731172558509355 Max: -3.3654115058060596 (Width: 1.3657610527032955)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.9578485131093744 Max: -2.3436808797608233 (Width: 1.614167633348551)
# Check Run 1 Number 14
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/14 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/14 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/14 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.25134223049439 Max: 1.437529942063942 (Width: 2.688872172558332)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -5.325473863079367 Max: -3.5955226599862167 (Width: 1.72995120309315)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -4.875694348181437 Max: -3.35175812934152 (Width: 1.5239362188399168)
# Check Run 1 Number 15
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/15 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/15 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/15 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.4371756566466267 Max: 1.4882218947086967 (Width: 1.9253975513553234)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -5.187812026076699 Max: -3.0560860757872454 (Width: 2.1317259502894537)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -4.793882890503188 Max: -2.814465150765233 (Width: 1.9794177397379547)
# Check Run 1 Number 16
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/16 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/16 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/16 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.1938133560517206 Max: 1.191584302876536 (Width: 2.3853976589282566)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -5

#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -6.559980383853048 Max: -5.050516083672996 (Width: 1.5094643001800527)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -4.432136210100401 Max: -2.9296850513819805 (Width: 1.5024511587184204)
# Check Run 1 Number 66
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/66 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/66 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/66 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 3.8328642158777404 Max: 6.070232062573799 (Width: 2.237367846696059)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -6.659091731121625 Max: -5.005695043994396 (Width: 1.6533966871272288)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -4.635018030696781 Max: -2.6735008430144425 (Width: 1.9615171876823383)
# Check Run 1 Number 67
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/67 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/67 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/67 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 2.5406600348440334 Max: 8.648205619083726 (Width: 6.107545584239692)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -6.328902362650557 Max: -4.776725259482529 (Width: 1.5521771031680283)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -4.807323709721145 Max: -2.9745036272553094 (Width: 1.8328200824658358)
# Check Run 1 Number 68
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/68 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/68 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/68 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 4.3722853550534735 Max: 7.783519968142771 (Width: 3.411234613089298)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -6.617890410544214 Max: -5.118289688031641 (Width: 1.4996007225125725)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -4.84723401939312 Max: -2.7615660794457986 (Width: 2.0856679399473217)
# Check Run 1 Number 69
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/69 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/69 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/69 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 2.717949092394556 Max: 5.648395669802442 (Width: 2.930446577407886)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -6.103154825537782 Max: -4.720619204740817 (Width: 1.3825356207969648)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -4.659743601763234 Max: -2.6460747711562482 (Width: 2.0136688306069854)
# Check Run 1 Number 7
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/7 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/7 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/7 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.3557265204326208 Max: 1.1909566477419808 (Width: 2.5466831681746016)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.1482387187211387 Max: 1.451896604401015 (Width: 1.3036578856798764)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.3191564936616764 Max: 2.138929128247802 (Width: 2.458085621909478)
# Check Run 1 Number 8
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/8 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/8 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/8 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.7309486505699514 Max: 3.3228444254572054 (Width: 2.591895774887254)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.6431466837482192 Max: 0.8908464084901979 (Width: 1.533993092238417)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.865818931515816 Max: 1.2182524997242483 (Width: 2.0840714312400643)
# Check Run 1 Number 9
#   Aggregating...
#     Current folder: ../../results_all/app_history_vm/run1/9 with 22 files
#     Current folder: ../../results_all/app_history_vm/run2/9 with 22 files
#     Current folder: ../../results_all/app_history_vm/run3/9 with 22 files
#   Running bootstrapping for type inserts...
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.20875684522078108 Max: 1.1920228517190656 (Width: 1.4007796969398467)
#   Running bootstrapping for type simple queries...
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.7292345102169473 Max: 9.523755322606053 (Width: 10.252989832823001)
#   Running bootstrapping for type group-by queries...
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.5931963541921057 Max: 1.5698533258843073 (Width: 3.163049680076413)
# Check Run 2 Number 1
#   Already aggregated, skip
# Check Run 2 Number 10
#   Already aggregated, skip
# Check Run 2 Number 11
#   Already aggregated, skip
# Check Run 2 Number 12
#   Already aggregated, skip
# Check Run 2 Number 13
#   Already aggregated, skip
# Check Run 2 Number 14
#   Already aggregated, skip
# Check Run 2 Number 15
#   Already aggregated, skip
# Check Run 2 Number 16
#   Already aggregated, skip
# Check Run 2 Number 17
#   Already aggregated, skip
# Check Run 2 Number 18
#   Already aggregated, skip
# Check Run 2 Number 19
#   Already aggregated, skip
# Check Run 2 Number 2
#   Already aggregated, skip
# Check Run 2 Number 20
#   Already aggregated, skip
# Check Run 2 Number 21
#   Already aggregated, skip
# Check Run 2 Number 22
#   Already aggregated, skip
# Check Run 2 Number 23
#   Already aggregated, skip
# Check Run 2 Number 24
#   Already aggregated, skip
# Check Run 2 Number 25
#   Already aggregated, skip
# Check Run 2 Number 26
#   Already aggregated, skip
# Check Run 2 Number 27
#   Already aggregated, skip
# Check Run 2 Number 28
#   Already aggregated, skip
# Check Run 2 Number 29
#   Already aggregated, skip
# Check Run 2 Number 3
#   Already aggregated, skip
# Check Run 2 Number 30
#   Already aggregated, skip
# Check Run 2 Number 31
#   Already aggregated, skip
# Check Run 2 Number 32
#   Already aggregated, skip
# Check Run 2 Number 33
#   Already aggregated, skip
# Check Run 2 Number 34
#   Already aggregated, skip
# Check Run 2 Number 35
#   Already aggregated, skip
# Check Run 2 Number 36
#   Already aggregated, skip
# Check Run 2 Number 37
#   Already aggregated, skip
# Check Run 2 Number 38
#   Already aggregated, skip
# Check Run 2 Number 39
#   Already aggregated, skip
# Check Run 2 Number 4
#   Already aggregated, skip
# Check Run 2 Number 40
#   Already aggregated, skip
# Check Run 2 Number 41
#   Already aggregated, skip
# Check Run 2 Number 42
#   Already aggregated, skip
# Check Run 2 Number 43
#   Already aggregated, skip
# Check Run 2 Number 44
#   Already aggregated, skip
# Check Run 2 Number 45
#   Already aggregated, skip
# Check Run 2 Number 46
#   Already aggregated, skip
# Check Run 2 Number 47
#   Already aggregated, skip
# Check Run 2 Number 48
#   Already aggregated, skip
# Check Run 2 Number 49
#   Already aggregated, skip
# Check Run 2 Number 5
#   Already aggregated, skip
# Check Run 2 Number 50
#   Already aggregated, skip
# Check Run 2 Number 51
#   Already aggregated, skip
# Check Run 2 Number 52
#   Already aggregated, skip
# Check Run 2 Number 53
#   Already aggregated, skip
# Check Run 2 Number 54
#   Already aggregated, skip
# Check Run 2 Number 55
#   Already aggregated, skip
# Check Run 2 Number 56
#   Already aggregated, skip
# Check Run 2 Number 57
#   Already aggregated, skip
# Check Run 2 Number 58
#   Already aggregated, skip
# Check Run 2 Number 59
#   Already aggregated, skip
# Check Run 2 Number 6
#   Already aggregated, skip
# Check Run 2 Number 60
#   Already aggregated, skip
# Check Run 2 Number 61
#   Already aggregated, skip
# Check Run 2 Number 62
#   Already aggregated, skip
# Check Run 2 Number 63
#   Already aggregated, skip
# Check Run 2 Number 64
#   Already aggregated, skip
# Check Run 2 Number 65
#   Already aggregated, skip
# Check Run 2 Number 66
#   Already aggregated, skip
# Check Run 2 Number 67
#   Already aggregated, skip
# Check Run 2 Number 68
#   Already aggregated, skip
# Check Run 2 Number 69
#   Already aggregated, skip
# Check Run 2 Number 7
#   Already aggregated, skip
# Check Run 2 Number 8
#   Already aggregated, skip
# Check Run 2 Number 9
#   Already aggregated, skip
# Check Run 3 Number 1
#   Already aggregated, skip
# Check Run 3 Number 10
#   Already aggregated, skip
# Check Run 3 Number 11
#   Already aggregated, skip
# Check Run 3 Number 12
#   Already aggregated, skip
# Check Run 3 Number 13
#   Already aggregated, skip
# Check Run 3 Number 14
#   Already aggregated, skip
# Check Run 3 Number 15
#   Already aggregated, skip
# Check Run 3 Number 16
#   Already aggregated, skip
# Check Run 3 Number 17
#   Already aggregated, skip
# Check Run 3 Number 18
#   Already aggregated, skip
# Check Run 3 Number 19
#   Already aggregated, skip
# Check Run 3 Number 2
#   Already aggregated, skip
# Check Run 3 Number 20
#   Already aggregated, skip
# Check Run 3 Number 21
#   Already aggregated, skip
# Check Run 3 Number 22
#   Already aggregated, skip
# Check Run 3 Number 23
#   Already aggregated, skip
# Check Run 3 Number 24
#   Already aggregated, skip
# Check Run 3 Number 25
#   Already aggregated, skip
# Check Run 3 Number 26
#   Already aggregated, skip
# Check Run 3 Number 27
#   Already aggregated, skip
# Check Run 3 Number 28
#   Already aggregated, skip
# Check Run 3 Number 29
#   Already aggregated, skip
# Check Run 3 Number 3
#   Already aggregated, skip
# Check Run 3 Number 30
#   Already aggregated, skip
# Check Run 3 Number 31
#   Already aggregated, skip
# Check Run 3 Number 32
#   Already aggregated, skip
# Check Run 3 Number 33
#   Already aggregated, skip
# Check Run 3 Number 34
#   Already aggregated, skip
# Check Run 3 Number 35
#   Already aggregated, skip
# Check Run 3 Number 36
#   Already aggregated, skip
# Check Run 3 Number 37
#   Already aggregated, skip
# Check Run 3 Number 38
#   Already aggregated, skip
# Check Run 3 Number 39
#   Already aggregated, skip
# Check Run 3 Number 4
#   Already aggregated, skip
# Check Run 3 Number 40
#   Already aggregated, skip
# Check Run 3 Number 41
#   Already aggregated, skip
# Check Run 3 Number 42
#   Already aggregated, skip
# Check Run 3 Number 43
#   Already aggregated, skip
# Check Run 3 Number 44
#   Already aggregated, skip
# Check Run 3 Number 45
#   Already aggregated, skip
# Check Run 3 Number 46
#   Already aggregated, skip
# Check Run 3 Number 47
#   Already aggregated, skip
# Check Run 3 Number 48
#   Already aggregated, skip
# Check Run 3 Number 49
#   Already aggregated, skip
# Check Run 3 Number 5
#   Already aggregated, skip
# Check Run 3 Number 50
#   Already aggregated, skip
# Check Run 3 Number 51
#   Already aggregated, skip
# Check Run 3 Number 52
#   Already aggregated, skip
# Check Run 3 Number 53
#   Already aggregated, skip
# Check Run 3 Number 54
#   Already aggregated, skip
# Check Run 3 Number 55
#   Already aggregated, skip
# Check Run 3 Number 56
#   Already aggregated, skip
# Check Run 3 Number 57
#   Already aggregated, skip
# Check Run 3 Number 58
#   Already aggregated, skip
# Check Run 3 Number 59
#   Already aggregated, skip
# Check Run 3 Number 6
#   Already aggregated, skip
# Check Run 3 Number 60
#   Already aggregated, skip
# Check Run 3 Number 61
#   Already aggregated, skip
# Check Run 3 Number 62
#   Already aggregated, skip
# Check Run 3 Number 63
#   Already aggregated, skip
# Check Run 3 Number 64
#   Already aggregated, skip
# Check Run 3 Number 65
#   Already aggregated, skip
# Check Run 3 Number 66
#   Already aggregated, skip
# Check Run 3 Number 67
#   Already aggregated, skip
# Check Run 3 Number 68
#   Already aggregated, skip
# Check Run 3 Number 69
#   Already aggregated, skip
# Check Run 3 Number 7
#   Already aggregated, skip
# Check Run 3 Number 8
#   Already aggregated, skip
# Check Run 3 Number 9
#   Already aggregated, skip
