# %%
import pandas as pd
import glob
from pathlib import Path
import numpy as np
from numpy.random import default_rng
rng = default_rng()


folder = "../../results_all/app_history_influxdb/"
filePrefix = "../../results_all/app_bootstrap_influx/app_bootstrap_influxdb"
print(folder)

start = 0.05
end = 0.2

numberOfSamples = 10000
CIsmall = 1
# Out:
# ../../results_all/app_history_influxdb/

# %%
def resample(perfRuntimes1: pd.DataFrame,
            perfRuntimes2: pd.DataFrame,
            instanceRuns: np.ndarray,
            samples: int,
            numberOfSamples: int) -> np.ndarray:
    """
        Resamples performances using hierarchical bootstrapping for building confindence intervals

        Builds a tensor of random indices of a form numberOfSamples * instanceRunsNumber * suiteRunsNumber * numberOfIterations.
        Then uses these indices to choose from a performance runtimes tensor with a form instanceRunsNumber * suiteRunsNumber * numberOfIterations.
        Finally, reshapes resulting tensor to a matrix of form numberOfSamples * ( instanceRunsNumber * suiteRunsNumber * numberOfIterations)
        and calculates performance differences between medians.

        Parameters
        ----------
        perfRuntimes1 : performance runtimes of the first version.
        perfRuntimes2 : performance runtimes of the second version.
        instanceRuns : array of instanceRun numbers
        samples : number of drawn alues

        Returns
        -------
        np.ndarray
            array of performance differences with a shape numberOfSample * 1.

        """
    instanceRunsNumber = instanceRuns.shape[0]

    allRuntimes1 = np.ndarray((instanceRunsNumber, samples))
    allRuntimes2 = np.ndarray((instanceRunsNumber, samples))


    for instanceRun in instanceRuns:
        allRuntimes1[instanceRun - 1]= perfRuntimes1.loc[(perfRuntimes1['run'] == instanceRun),
                                                'latency (ms)'].to_numpy()
        allRuntimes2[instanceRun - 1]= perfRuntimes2.loc[(perfRuntimes2['run'] == instanceRun),
                                                'latency (ms)'].to_numpy()

    medians = []
    for i in range(numberOfSamples):
        #if (i % 1000 == 0):
        #    print(f"i is {i}")
        #Generate Random Arrays
        currentInstanceRun = rng.choice(instanceRuns, size=(instanceRunsNumber)) - 1
        currentRuntimes1 = rng.integers(samples, size=(samples, instanceRunsNumber))
        currentRuntimes2 = rng.integers(samples, size=(samples, instanceRunsNumber))
        #Bulk selection
        tmp1 = allRuntimes1[currentInstanceRun, currentRuntimes1]
        tmp1 = tmp1.reshape((instanceRunsNumber * samples))

        tmp2 = allRuntimes2[currentInstanceRun, currentRuntimes2]
        tmp2 = tmp2.reshape((instanceRunsNumber * samples))

        # Get median for both lists
        med1 = np.median(tmp1, axis=0)
        med2 = np.median(tmp2, axis=0)
        medians.append(med2/med1)

    return medians

def bootstrap(perfRuntimes1: pd.DataFrame,
            perfRuntimes2: pd.DataFrame):

    instanceRuns = perfRuntimes1.run.unique()
    numberOfInstanceRuns = len(instanceRuns)
    print(f"    Found {numberOfInstanceRuns} runs")
    R = resample(perfRuntimes1=perfRuntimes1,
                 perfRuntimes2=perfRuntimes2,
                 instanceRuns=instanceRuns,
                 samples=int(len(perfRuntimes1) / numberOfInstanceRuns),
                 numberOfSamples=numberOfSamples)

    print(f"    Bootstrapping done ({len(R)} elements in R).")

    # Find conf. intervals
    R.sort()

    small = int((numberOfSamples * CIsmall) / 100 / 2)
    if small == 0:
        small  = 1

    minSmall = R[small-1]
    minSmall = (minSmall - 1) * 100
    maxSmall = R[numberOfSamples-small-1]
    maxSmall = (maxSmall - 1) * 100
    return minSmall, maxSmall


all_runs = glob.glob(folder + "*")

for fullRunFolder in all_runs:
    runFolder = fullRunFolder + "/"
    all_numbers = glob.glob(runFolder + "*")
    for fullNumberFolder in all_numbers:

        all_files = glob.glob(fullNumberFolder + "/*")
        size = len(all_files)

        if size != 17:
            print(f"{size} elements in folder {fullNumberFolder}, skip.")
        else:
            tmp = fullNumberFolder.split("\\")

            #Parse run and commit number from path structure
            run = tmp[len(tmp)-2]
            run=run[3:]
            commitNumber = tmp[len(tmp)-1]
            print(f"Check Run {run} Number {commitNumber}")

            filename = Path(filePrefix + "_" + commitNumber + ".csv")
            skip = False

            if filename.is_file():
                print("  Already aggregated, skip")
            else:
                print("  Aggregating...")
                rows = []
                for i in range(3):
                    currFolder = folder + "run" + str((i+1)) + "/" + str(commitNumber)
                    tmp = glob.glob(currFolder + "/*")
                    noOfFiles = len(tmp)
                    print(f"    Current folder: {currFolder} with {noOfFiles} files")




                    if noOfFiles != 17:
                        print(f"ERROR: {noOfFiles} elements in folder {currFolder}, skip.")
                        skip = True
                    else:

                        #Read latency file for both types (old and new)
                        insertsOld = pd.read_csv(currFolder + "/latenciesInsertsOld.csv",
                                         header=None,
                                         names=["worker","batch","latency (ms)"])
                        insertsOld.sort_values(by=["batch"], inplace=True)
                        number = len(insertsOld.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        insertsOld = insertsOld.iloc[removeFirst:-removeLast , :]

                        for index, row in insertsOld.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["batch"],
                                "type" : "inserts",
                                "version" : "base",
                                "latency (ms)" : row["latency (ms)"]
                            })

                        insertsNew = pd.read_csv(currFolder + "/latenciesInsertsNew.csv",
                                         header=None,
                                         names=["worker","batch","latency (ms)"])
                        insertsNew.sort_values(by=["batch"], inplace=True)
                        number = len(insertsNew.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        insertsNew = insertsNew.iloc[removeFirst:-removeLast , :]

                        for index, row in insertsNew.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["batch"],
                                "type" : "inserts",
                                "version" : "variation",
                                "latency (ms)" : row["latency (ms)"]
                            })

                        queries1Old = pd.read_csv(currFolder + "/latenciesQueries1Old.csv",
                                         header=None,
                                         names=["query","latency (ms)"])
                        queries1Old.sort_values(by=["query"], inplace=True)
                        number = len(queries1Old.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        queries1Old = queries1Old.iloc[removeFirst:-removeLast , :]


                        for index, row in queries1Old.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["query"],
                                "type" : "simple queries",
                                "version" : "base",
                                "latency (ms)" : row["latency (ms)"]
                            })

                        queries2Old = pd.read_csv(currFolder + "/latenciesQueries2Old.csv",
                                         header=None,
                                         names=["query","latency (ms)"])
                        queries2Old.sort_values(by=["query"], inplace=True)

                        number = len(queries2Old.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        queries2Old = queries2Old.iloc[removeFirst:-removeLast , :]

                        for index, row in queries2Old.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["query"],
                                "type" : "group-by queries",
                                "version" : "base",
                                "latency (ms)" : row["latency (ms)"]
                            })

                        queries1New = pd.read_csv(currFolder + "/latenciesQueries1New.csv",
                                         header=None,
                                         names=["query","latency (ms)"])
                        queries1New.sort_values(by=["query"], inplace=True)

                        number = len(queries1New.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        queries1New = queries1New.iloc[removeFirst:-removeLast , :]

                        for index, row in queries1New.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["query"],
                                "type" : "simple queries",
                                "version" : "variation",
                                "latency (ms)" : row["latency (ms)"]
                            })

                        queries2New = pd.read_csv(currFolder + "/latenciesQueries2New.csv",
                                         header=None,
                                         names=["query","latency (ms)"])
                        queries2New.sort_values(by=["query"], inplace=True)

                        number = len(queries2New.index)
                        removeFirst = int(start * number)
                        removeLast = int(end * number)
                        queries2New = queries2New.iloc[removeFirst:-removeLast , :]

                        for index, row in queries2New.iterrows():
                            rows.append({
                                "run":i+1,
                                "number": row["query"],
                                "type" : "group-by queries",
                                "version" : "variation",
                                "latency (ms)" : row["latency (ms)"]
                            })
                if not skip:

                    #Run bootstrapping for each type
                    result = []
                    df_latencies = pd.DataFrame(rows)
                    for type in df_latencies.type.unique():
                        benchmarkMeasurements = df_latencies.loc[(df_latencies['type'].str.startswith(type, na=False))]
                        perfRuntimes1 = benchmarkMeasurements.loc[(benchmarkMeasurements['version'] == "base")]
                        perfRuntimes2 = benchmarkMeasurements.loc[(benchmarkMeasurements['version'] == "variation")]

                        print(f"  Find median perf change for type {type}...")
                        median1 = perfRuntimes1["latency (ms)"].median()
                        median2 = perfRuntimes2["latency (ms)"].median()
                        diff = ((median2 / median1) - 1) * 100

                        print(f"  Running bootstrapping for type {type}...")
                        instanceRuns = benchmarkMeasurements.run.unique()
                        numberOfInstanceRuns = len(instanceRuns)

                        print(f"    Found {len(perfRuntimes1)} and {len(perfRuntimes2)} values")
                        min, max = bootstrap(perfRuntimes1, perfRuntimes2)
                        print(f"    Min: {min} Max: {max} (Width: {max-min})")
                        result.append({
                            "commit":commitNumber,
                            "type": type,
                            "min" : min,
                            "med" : diff,
                            "max" : max
                        })

                    # Convert to data frame
                    df_result = pd.DataFrame(result)
                    # Save to file
                    df_result.to_csv(str(filename))
# Out:
# Check Run 1 Number 1
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/1 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/1 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/1 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.6876670638267357 Max: 0.4657126010744861 (Width: 1.1533796649012218)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.4033293952155375 Max: 0.21520428123507074 (Width: 3.618533676450608)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.8206565872110883 Max: 0.6182244206383247 (Width: 1.438881007849413)
# Check Run 1 Number 10
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/10 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/10 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/10 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.045502220198423426 Max: 1.1923831610011204 (Width: 1.2378853811995438)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.5825816655171567 Max: 1.4695252414792082 (Width: 2.052106906996365)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.8479364566909897 Max: 1.9133841523511164 (Width: 2.761320609042106)
# Check Run 1 Number 100
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/100 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/100 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/100 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 15.00366701523783 Max: 16.751722406667824 (Width: 1.7480553914299932)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -10.595486188787683 Max: -6.034629214236819 (Width: 4.560856974550864)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.12817910156330825 Max: 2.163412963540723 (Width: 2.0352338619774146)
# Check Run 1 Number 101
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/101 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/101 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/101 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 14.404014238642503 Max: 15.280295631575358 (Width: 0.8762813929328548)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -9.376288421764356 Max: -5.422913286104869 (Width: 3.9533751356594866)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.02724189553131584 Max: 2.78453584399736 (Width: 2.811777739528676)
# Check Run 1 Number 102
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/102 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/102 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/102 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 14.97107211557973 Max: 16.544533851426667 (Width: 1.5734617358469372)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -9.483149106588861 Max: -5.376913008580009 (Width: 4.106236098008853)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 1.3517955318122166 Max: 2.965497317448329 (Width: 1.6137017856361124)
# Check Run 1 Number 103
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/103 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/103 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/103 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 14.48883109986021 Max: 15.896990269629917 (Width: 1.4081591697697071)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -7.458949808208093 Max: -3.734359647156371 (Width: 3.724590161051722)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.8952369981919173 Max: 3.4729975443667627 (Width: 2.5777605461748454)
# Check Run 1 Number 104
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/104 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/104 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/104 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 15.153971690317514 Max: 16.397094013810822 (Width: 1.2431223234933082)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -7.851084636796468 Max: -3.3010980155989245 (Width: 4.549986621197544)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.8618865422906241 Max: 3.82524939970581 (Width: 2.963362857415186)
# Check Run 1 Number 105
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/105 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/105 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/105 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 14.650558677314862 Max: 16.311565627243517 (Width: 1.6610069499286553)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -8.405379902478494 Max: -4.25596433866593 (Width: 4.149415563812564)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.2936973111006047 Max: 2.5340739035774273 (Width: 2.2403765924768226)
# Check Run 1 Number 106
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/106 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/106 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/106 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 14.7505548213527 Max: 15.996226928327584 (Width: 1.245672106974883)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -8.224606569897496 Max: -4.428352931859603 (Width: 3.796253638037893)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.40265018338649927 Max: 2.2382180520407857 (Width: 2.640868235427285)
# Check Run 1 Number 107
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/107 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/107 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/107 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 15.447348458971423 Max: 16.547908048104066 (Width: 1.1005595891326436)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -7.14160916020381 Max: -4.798476405518592 (Width: 2.343132754685218)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.805260833455046 Max: 3.0481855541059977 (Width: 2.2429247206509517)
# Check Run 1 Number 108
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/108 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/108 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/108 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 14.872190735663903 Max: 16.668202022723634 (Width: 1.7960112870597307)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -8.66828936222781 Max: -3.9398636491171035 (Width: 4.728425713110706)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.7522320376582403 Max: 3.2988396170724466 (Width: 2.5466075794142062)
# Check Run 1 Number 109
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/109 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/109 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/109 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 14.455382753165157 Max: 16.582112740828837 (Width: 2.12672998766368)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -8.652014139199583 Max: -5.766853898552126 (Width: 2.8851602406474566)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.41834453853968334 Max: 2.0312819517896763 (Width: 1.612937413249993)
# Check Run 1 Number 11
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/11 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/11 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/11 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.10391333042381046 Max: 0.6403576929599586 (Width: 0.744271023383769)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.0824372869085894 Max: 1.1587535477681543 (Width: 3.2411908346767437)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.0376377517600677 Max: 1.638660556703031 (Width: 2.6762983084630987)
# Check Run 1 Number 110
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/110 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/110 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/110 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 15.088453971247095 Max: 16.80791200553884 (Width: 1.719458034291744)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -8.144848940203186 Max: -5.467816126795755 (Width: 2.677032813407431)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.2564872829415421 Max: 2.4054331595343204 (Width: 2.1489458765927782)
# Check Run 1 Number 111
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/111 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/111 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/111 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 14.318262227293443 Max: 15.353791107923564 (Width: 1.035528880630121)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -9.657433975253815 Max: -4.721417928620298 (Width: 4.936016046633517)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.7645881597676984 Max: 1.984538128716018 (Width: 2.7491262884837164)
# Check Run 1 Number 12
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/12 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/12 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/12 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.8520026863364727 Max: 0.2771807450761221 (Width: 1.1291834314125948)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.1316429654257387 Max: 2.467033451457623 (Width: 3.598676416883362)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.2313883391136704 Max: 1.5347757103733928 (Width: 2.766164049487063)
# Check Run 1 Number 13
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/13 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/13 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/13 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.7200105478488705 Max: 0.18325733198931715 (Width: 0.9032678798381877)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.0007228628006968 Max: 2.9454666186736755 (Width: 4.946189481474372)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.7438350938033373 Max: 2.051946676748484 (Width: 4.795781770551821)
# Check Run 1 Number 14
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/14 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/14 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/14 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.0332661730853898 Max: 1.1676860534981959 (Width: 2.2009522265835857)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.7523568424534064 Max: 0.40317188463050435 (Width: 2.1555287270839107)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.554368123208394 Max: 1.5959949751534586 (Width: 3.1503630983618525)
# Check Run 1 Number 15
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/15 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/15 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/15 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.6480514979648966 Max: 0.4148331704276531 (Width: 1.0628846683925497)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.0770053737166014 Max: 2.498431473097318 (Width: 5.575436846813919)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.2714763926724437 Max: 1.9686866885338494 (Width: 3.240163081206293)
# Check Run 1 Number 16
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/16 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/16 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/16 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.5988027427002329 Max: 0.7287953137978365 (Width: 1.3275980564980694)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.776047582062267 Max: 1.5171379946640196 (Width: 2.2931855767262865)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.7126427082300721 Max: 0.23510286757653098 (Width: 1.9477455758066031)
# Check Run 1 Number 17
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/17 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/17 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/17 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.2988216865225222 Max: 0.4296541483529204 (Width: 1.7284758348754425)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.5776893126351794 Max: 1.9261887670581235 (Width: 5.503878079693303)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.6445986565949977 Max: 0.22051823619002597 (Width: 1.8651168927850237)
# Check Run 1 Number 18
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/18 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/18 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/18 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.5640209914447469 Max: 0.5238361868141528 (Width: 1.0878571782588997)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.821853365187289 Max: 0.4613895526914824 (Width: 4.283242917878772)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.2636231503228466 Max: 0.39312437694489777 (Width: 2.6567475272677443)
# Check Run 1 Number 19
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/19 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/19 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/19 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.36213475203485945 Max: 0.8994149244055283 (Width: 1.2615496764403877)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.7077444722583879 Max: 0.5648527025593708 (Width: 2.2725971748177587)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.9075734234838992 Max: 0.8288317105090259 (Width: 2.736405133992925)
# Check Run 1 Number 2
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/2 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/2 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/2 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.3339691358342112 Max: 0.3021671954358318 (Width: 0.636136331270043)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.0111793796025355 Max: 2.6152356138001043 (Width: 5.62641499340264)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.768690518509164 Max: 1.358767332663624 (Width: 3.127457851172788)
# Check Run 1 Number 20
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/20 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/20 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/20 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.582531626853755 Max: 0.521624128754139 (Width: 1.104155755607894)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.736900843661394 Max: 1.5967992027036138 (Width: 4.333700046365008)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.1618349025603334 Max: 0.35687782957833925 (Width: 2.5187127321386726)
# Check Run 1 Number 21
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/21 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/21 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/21 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.7283941059328058 Max: 0.6044954022320415 (Width: 1.3328895081648473)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.305473651772949 Max: 2.0189462627703936 (Width: 4.324419914543343)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.7053841226170707 Max: 0.3663261803068085 (Width: 2.0717103029238793)
# Check Run 1 Number 22
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/22 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/22 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/22 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.18260186698088043 Max: 1.1756497490110762 (Width: 1.3582516159919567)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.9412545341128009 Max: 1.202449579089171 (Width: 2.143704113201972)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.5357637362638843 Max: 0.17537512237129071 (Width: 1.711138858635175)
# Check Run 1 Number 23
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/23 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/23 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/23 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.29968994583823294 Max: 0.6073925982757578 (Width: 0.9070825441139907)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.6591226742208818 Max: 1.5021762856480603 (Width: 4.161298959868942)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.9320143384972233 Max: 0.13781244511807955 (Width: 2.069826783615303)
# Check Run 1 Number 24
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/24 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/24 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/24 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.28547782824291934 Max: 0.5898429004567163 (Width: 0.8753207286996356)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.358120804071163 Max: 1.0489969339558147 (Width: 4.407117738026978)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.705472527506513 Max: 0.4191645692031898 (Width: 2.124637096709703)
# Check Run 1 Number 25
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/25 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/25 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/25 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.7404402923329667 Max: 0.028239754075154444 (Width: 0.7686800464081212)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.801881636281567 Max: 0.9327388908190404 (Width: 3.734620527100607)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.4067168601733848 Max: 0.44156403454032045 (Width: 1.8482808947137053)
# Check Run 1 Number 26
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/26 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/26 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/26 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.301646909788289 Max: 0.7352844342179088 (Width: 1.0369313440061978)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.1080583208612946 Max: 1.3880821297526547 (Width: 3.4961404506139493)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.7387254502235994 Max: 0.35867241092348845 (Width: 2.097397861147088)
# Check Run 1 Number 27
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/27 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/27 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/27 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.3114638033098527 Max: 0.3978298609136788 (Width: 0.7092936642235315)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.1950145639178196 Max: 1.2429536254210172 (Width: 4.437968189338837)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.8784868952902647 Max: 0.39270652941987283 (Width: 1.2711934247101375)
# Check Run 1 Number 28
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/28 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/28 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/28 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.76798253067214 Max: 0.7273386425763473 (Width: 1.4953211732484872)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.5775218897692058 Max: 3.4552582278010835 (Width: 2.8777363380318777)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.137185986177703 Max: 0.1016191503786068 (Width: 2.23880513655631)
# Check Run 1 Number 29
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/29 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/29 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/29 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.7980898551300575 Max: 0.4001806679222675 (Width: 1.198270523052325)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.559724237389217 Max: 0.15323611569055817 (Width: 3.712960353079775)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.8005055374373247 Max: 0.8970961028496927 (Width: 2.6976016402870173)
# Check Run 1 Number 3
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/3 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/3 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/3 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.5719644168500793 Max: 0.2424204772005556 (Width: 0.8143848940506349)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.509504492005199 Max: 0.6611589024496878 (Width: 3.1706633944548868)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.6923623384725963 Max: 1.7686284250758355 (Width: 2.460990763548432)
# Check Run 1 Number 30
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/30 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/30 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/30 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.7582162139233017 Max: 0.8968861133518358 (Width: 1.6551023272751375)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.6560690981419 Max: -0.4251923660798629 (Width: 2.230876732062037)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.314881721491424 Max: -0.18701631080285663 (Width: 2.1278654106885675)
# Check Run 1 Number 31
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/31 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/31 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/31 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.5066597298447828 Max: 0.41997585996500497 (Width: 0.9266355898097878)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.2979768490360772 Max: 2.1212625803330054 (Width: 5.419239429369083)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.7324804709647812 Max: 0.822274115454702 (Width: 2.554754586419483)
# Check Run 1 Number 32
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/32 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/32 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/32 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.1499736969133858 Max: 0.9580140128073067 (Width: 0.8080403158939209)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.3328513085254947 Max: 2.9676872547397704 (Width: 2.6348359462142756)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.1885985667761445 Max: 1.4033929745942642 (Width: 2.5919915413704087)
# Check Run 1 Number 33
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/33 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/33 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/33 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.14047166763280217 Max: 1.5483776823607576 (Width: 1.6888493499935597)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.028455145329542297 Max: 2.5677389718270494 (Width: 2.5961941171565917)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.4109292869795564 Max: 1.515547465284528 (Width: 2.9264767522640844)
# Check Run 1 Number 34
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/34 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/34 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/34 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.16381341655267168 Max: 1.5639453335247078 (Width: 1.7277587500773794)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.3950199886386563 Max: 1.9121037574825417 (Width: 2.307123746121198)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.7743416260046598 Max: 1.4901506172346313 (Width: 2.264492243239291)
# Check Run 1 Number 35
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/35 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/35 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/35 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.7106198795143737 Max: 1.3616354876087922 (Width: 0.6510156080944185)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -3.988296128154134 Max: 0.7924577657922205 (Width: 4.780753893946354)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.9716527655116769 Max: 1.3162516329565666 (Width: 2.2879043984682434)
# Check Run 1 Number 36
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/36 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/36 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/36 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.3814153247174268 Max: 1.176746866328382 (Width: 0.7953315416109552)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.833954575556628 Max: 2.265623465738975 (Width: 3.099578041295603)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -2.2254265929366857 Max: 0.6992272397164934 (Width: 2.924653832653179)
# Check Run 1 Number 37
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/37 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/37 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/37 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.5439378371618231 Max: 0.5351149897951046 (Width: 1.0790528269569277)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -25.654411407129484 Max: -22.32921807652376 (Width: 3.3251933306057246)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -5.165725076189975 Max: -3.049477759976449 (Width: 2.1162473162135265)
# Check Run 1 Number 38
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/38 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/38 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/38 with 17 files
# ...
#     Min: -9.286941374543256 Max: -6.6195404007284075 (Width: 2.667400973814848)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -1.200388034157085 Max: 1.7949708117220187 (Width: 2.9953588458791036)
# Check Run 1 Number 96
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/96 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/96 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/96 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 15.017671426076106 Max: 16.074957218938323 (Width: 1.057285792862217)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -7.467388775819861 Max: -4.908250326848629 (Width: 2.5591384489712325)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.5343486024996014 Max: 2.6614146754173396 (Width: 3.195763277916941)
# Check Run 1 Number 97
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/97 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/97 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/97 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 15.437669727326252 Max: 16.400876436805834 (Width: 0.9632067094795822)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -8.66669973234121 Max: -4.752568733733675 (Width: 3.9141309986075346)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.532039757863767 Max: 3.3121736001897384 (Width: 3.8442133580535054)
# Check Run 1 Number 98
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/98 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/98 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/98 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 14.278331194745464 Max: 15.38134510731879 (Width: 1.103013912573326)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -7.571594029330564 Max: -4.515544719032894 (Width: 3.05604931029767)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 0.23654432438047213 Max: 2.3570732201565914 (Width: 2.1205288957761192)
# Check Run 1 Number 99
#   Aggregating...
#     Current folder: ../../results_all/app_history_influxdb/run1/99 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run2/99 with 17 files
#     Current folder: ../../results_all/app_history_influxdb/run3/99 with 17 files
#   Find median perf change for type inserts...
#   Running bootstrapping for type inserts...
#     Found 340200 and 340200 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: 14.483149773169156 Max: 17.101451691562765 (Width: 2.618301918393609)
#   Find median perf change for type simple queries...
#   Running bootstrapping for type simple queries...
#     Found 2271 and 2271 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -7.8944951871933515 Max: -4.589101043124499 (Width: 3.3053941440688526)
#   Find median perf change for type group-by queries...
#   Running bootstrapping for type group-by queries...
#     Found 381 and 381 values
#     Found 3 runs
#     Bootstrapping done (10000 elements in R).
#     Min: -0.07934722058509092 Max: 2.7213816907597943 (Width: 2.800728911344885)
# Check Run 2 Number 1
#   Already aggregated, skip
# Check Run 2 Number 10
#   Already aggregated, skip
# Check Run 2 Number 100
#   Already aggregated, skip
# Check Run 2 Number 101
#   Already aggregated, skip
# Check Run 2 Number 102
#   Already aggregated, skip
# Check Run 2 Number 103
#   Already aggregated, skip
# Check Run 2 Number 104
#   Already aggregated, skip
# Check Run 2 Number 105
#   Already aggregated, skip
# Check Run 2 Number 106
#   Already aggregated, skip
# Check Run 2 Number 107
#   Already aggregated, skip
# Check Run 2 Number 108
#   Already aggregated, skip
# Check Run 2 Number 109
#   Already aggregated, skip
# Check Run 2 Number 11
#   Already aggregated, skip
# Check Run 2 Number 110
#   Already aggregated, skip
# Check Run 2 Number 111
#   Already aggregated, skip
# Check Run 2 Number 12
#   Already aggregated, skip
# Check Run 2 Number 13
#   Already aggregated, skip
# Check Run 2 Number 14
#   Already aggregated, skip
# Check Run 2 Number 15
#   Already aggregated, skip
# Check Run 2 Number 16
#   Already aggregated, skip
# Check Run 2 Number 17
#   Already aggregated, skip
# Check Run 2 Number 18
#   Already aggregated, skip
# Check Run 2 Number 19
#   Already aggregated, skip
# Check Run 2 Number 2
#   Already aggregated, skip
# Check Run 2 Number 20
#   Already aggregated, skip
# Check Run 2 Number 21
#   Already aggregated, skip
# Check Run 2 Number 22
#   Already aggregated, skip
# Check Run 2 Number 23
#   Already aggregated, skip
# Check Run 2 Number 24
#   Already aggregated, skip
# Check Run 2 Number 25
#   Already aggregated, skip
# Check Run 2 Number 26
#   Already aggregated, skip
# Check Run 2 Number 27
#   Already aggregated, skip
# Check Run 2 Number 28
#   Already aggregated, skip
# Check Run 2 Number 29
#   Already aggregated, skip
# Check Run 2 Number 3
#   Already aggregated, skip
# Check Run 2 Number 30
#   Already aggregated, skip
# Check Run 2 Number 31
#   Already aggregated, skip
# Check Run 2 Number 32
#   Already aggregated, skip
# Check Run 2 Number 33
#   Already aggregated, skip
# Check Run 2 Number 34
#   Already aggregated, skip
# Check Run 2 Number 35
#   Already aggregated, skip
# Check Run 2 Number 36
#   Already aggregated, skip
# Check Run 2 Number 37
#   Already aggregated, skip
# Check Run 2 Number 38
#   Already aggregated, skip
# Check Run 2 Number 39
#   Already aggregated, skip
# Check Run 2 Number 4
#   Already aggregated, skip
# Check Run 2 Number 40
#   Already aggregated, skip
# Check Run 2 Number 41
#   Already aggregated, skip
# Check Run 2 Number 42
#   Already aggregated, skip
# Check Run 2 Number 43
#   Already aggregated, skip
# Check Run 2 Number 44
#   Already aggregated, skip
# Check Run 2 Number 45
#   Already aggregated, skip
# Check Run 2 Number 46
#   Already aggregated, skip
# Check Run 2 Number 47
#   Already aggregated, skip
# Check Run 2 Number 48
#   Already aggregated, skip
# Check Run 2 Number 49
#   Already aggregated, skip
# Check Run 2 Number 5
#   Already aggregated, skip
# Check Run 2 Number 50
#   Already aggregated, skip
# Check Run 2 Number 51
#   Already aggregated, skip
# Check Run 2 Number 52
#   Already aggregated, skip
# Check Run 2 Number 53
#   Already aggregated, skip
# Check Run 2 Number 54
#   Already aggregated, skip
# Check Run 2 Number 55
#   Already aggregated, skip
# Check Run 2 Number 56
#   Already aggregated, skip
# Check Run 2 Number 57
#   Already aggregated, skip
# Check Run 2 Number 58
#   Already aggregated, skip
# Check Run 2 Number 59
#   Already aggregated, skip
# Check Run 2 Number 6
#   Already aggregated, skip
# Check Run 2 Number 60
#   Already aggregated, skip
# Check Run 2 Number 61
#   Already aggregated, skip
# Check Run 2 Number 62
#   Already aggregated, skip
# Check Run 2 Number 63
#   Already aggregated, skip
# Check Run 2 Number 64
#   Already aggregated, skip
# Check Run 2 Number 65
#   Already aggregated, skip
# Check Run 2 Number 66
#   Already aggregated, skip
# Check Run 2 Number 67
#   Already aggregated, skip
# Check Run 2 Number 68
#   Already aggregated, skip
# Check Run 2 Number 69
#   Already aggregated, skip
# Check Run 2 Number 7
#   Already aggregated, skip
# Check Run 2 Number 70
#   Already aggregated, skip
# Check Run 2 Number 71
#   Already aggregated, skip
# Check Run 2 Number 72
#   Already aggregated, skip
# Check Run 2 Number 73
#   Already aggregated, skip
# Check Run 2 Number 74
#   Already aggregated, skip
# Check Run 2 Number 75
#   Already aggregated, skip
# Check Run 2 Number 76
#   Already aggregated, skip
# Check Run 2 Number 77
#   Already aggregated, skip
# Check Run 2 Number 78
#   Already aggregated, skip
# Check Run 2 Number 79
#   Already aggregated, skip
# Check Run 2 Number 8
#   Already aggregated, skip
# Check Run 2 Number 80
#   Already aggregated, skip
# Check Run 2 Number 81
#   Already aggregated, skip
# Check Run 2 Number 82
#   Already aggregated, skip
# Check Run 2 Number 83
#   Already aggregated, skip
# Check Run 2 Number 84
#   Already aggregated, skip
# Check Run 2 Number 85
#   Already aggregated, skip
# Check Run 2 Number 86
#   Already aggregated, skip
# Check Run 2 Number 87
#   Already aggregated, skip
# Check Run 2 Number 88
#   Already aggregated, skip
# 14 elements in folder ../../results_all/app_history_influxdb\run2\89, skip.
# Check Run 2 Number 9
#   Already aggregated, skip
# 14 elements in folder ../../results_all/app_history_influxdb\run2\90, skip.
# 14 elements in folder ../../results_all/app_history_influxdb\run2\91, skip.
# 14 elements in folder ../../results_all/app_history_influxdb\run2\92, skip.
# 14 elements in folder ../../results_all/app_history_influxdb\run2\93, skip.
# 14 elements in folder ../../results_all/app_history_influxdb\run2\94, skip.
# Check Run 2 Number 95
#   Already aggregated, skip
# Check Run 2 Number 96
#   Already aggregated, skip
# Check Run 2 Number 97
#   Already aggregated, skip
# Check Run 2 Number 98
#   Already aggregated, skip
# Check Run 2 Number 99
#   Already aggregated, skip
# Check Run 3 Number 1
#   Already aggregated, skip
# Check Run 3 Number 10
#   Already aggregated, skip
# Check Run 3 Number 100
#   Already aggregated, skip
# Check Run 3 Number 101
#   Already aggregated, skip
# Check Run 3 Number 102
#   Already aggregated, skip
# Check Run 3 Number 103
#   Already aggregated, skip
# Check Run 3 Number 104
#   Already aggregated, skip
# Check Run 3 Number 105
#   Already aggregated, skip
# Check Run 3 Number 106
#   Already aggregated, skip
# Check Run 3 Number 107
#   Already aggregated, skip
# Check Run 3 Number 108
#   Already aggregated, skip
# Check Run 3 Number 109
#   Already aggregated, skip
# Check Run 3 Number 11
#   Already aggregated, skip
# Check Run 3 Number 110
#   Already aggregated, skip
# Check Run 3 Number 111
#   Already aggregated, skip
# Check Run 3 Number 12
#   Already aggregated, skip
# Check Run 3 Number 13
#   Already aggregated, skip
# Check Run 3 Number 14
#   Already aggregated, skip
# Check Run 3 Number 15
#   Already aggregated, skip
# Check Run 3 Number 16
#   Already aggregated, skip
# Check Run 3 Number 17
#   Already aggregated, skip
# Check Run 3 Number 18
#   Already aggregated, skip
# Check Run 3 Number 19
#   Already aggregated, skip
# Check Run 3 Number 2
#   Already aggregated, skip
# Check Run 3 Number 20
#   Already aggregated, skip
# Check Run 3 Number 21
#   Already aggregated, skip
# Check Run 3 Number 22
#   Already aggregated, skip
# Check Run 3 Number 23
#   Already aggregated, skip
# Check Run 3 Number 24
#   Already aggregated, skip
# Check Run 3 Number 25
#   Already aggregated, skip
# Check Run 3 Number 26
#   Already aggregated, skip
# Check Run 3 Number 27
#   Already aggregated, skip
# Check Run 3 Number 28
#   Already aggregated, skip
# Check Run 3 Number 29
#   Already aggregated, skip
# Check Run 3 Number 3
#   Already aggregated, skip
# Check Run 3 Number 30
#   Already aggregated, skip
# Check Run 3 Number 31
#   Already aggregated, skip
# Check Run 3 Number 32
#   Already aggregated, skip
# Check Run 3 Number 33
#   Already aggregated, skip
# Check Run 3 Number 34
#   Already aggregated, skip
# Check Run 3 Number 35
#   Already aggregated, skip
# Check Run 3 Number 36
#   Already aggregated, skip
# Check Run 3 Number 37
#   Already aggregated, skip
# Check Run 3 Number 38
#   Already aggregated, skip
# Check Run 3 Number 39
#   Already aggregated, skip
# Check Run 3 Number 4
#   Already aggregated, skip
# Check Run 3 Number 40
#   Already aggregated, skip
# Check Run 3 Number 41
#   Already aggregated, skip
# Check Run 3 Number 42
#   Already aggregated, skip
# Check Run 3 Number 43
#   Already aggregated, skip
# Check Run 3 Number 44
#   Already aggregated, skip
# Check Run 3 Number 45
#   Already aggregated, skip
# Check Run 3 Number 46
#   Already aggregated, skip
# Check Run 3 Number 47
#   Already aggregated, skip
# Check Run 3 Number 48
#   Already aggregated, skip
# Check Run 3 Number 49
#   Already aggregated, skip
# Check Run 3 Number 5
#   Already aggregated, skip
# Check Run 3 Number 50
#   Already aggregated, skip
# Check Run 3 Number 51
#   Already aggregated, skip
# Check Run 3 Number 52
#   Already aggregated, skip
# Check Run 3 Number 53
#   Already aggregated, skip
# Check Run 3 Number 54
#   Already aggregated, skip
# Check Run 3 Number 55
#   Already aggregated, skip
# Check Run 3 Number 56
#   Already aggregated, skip
# Check Run 3 Number 57
#   Already aggregated, skip
# Check Run 3 Number 58
#   Already aggregated, skip
# Check Run 3 Number 59
#   Already aggregated, skip
# Check Run 3 Number 6
#   Already aggregated, skip
# Check Run 3 Number 60
#   Already aggregated, skip
# Check Run 3 Number 61
#   Already aggregated, skip
# Check Run 3 Number 62
#   Already aggregated, skip
# Check Run 3 Number 63
#   Already aggregated, skip
# Check Run 3 Number 64
#   Already aggregated, skip
# Check Run 3 Number 65
#   Already aggregated, skip
# Check Run 3 Number 66
#   Already aggregated, skip
# Check Run 3 Number 67
#   Already aggregated, skip
# Check Run 3 Number 68
#   Already aggregated, skip
# Check Run 3 Number 69
#   Already aggregated, skip
# Check Run 3 Number 7
#   Already aggregated, skip
# Check Run 3 Number 70
#   Already aggregated, skip
# Check Run 3 Number 71
#   Already aggregated, skip
# Check Run 3 Number 72
#   Already aggregated, skip
# Check Run 3 Number 73
#   Already aggregated, skip
# Check Run 3 Number 74
#   Already aggregated, skip
# Check Run 3 Number 75
#   Already aggregated, skip
# Check Run 3 Number 76
#   Already aggregated, skip
# Check Run 3 Number 77
#   Already aggregated, skip
# Check Run 3 Number 78
#   Already aggregated, skip
# Check Run 3 Number 79
#   Already aggregated, skip
# Check Run 3 Number 8
#   Already aggregated, skip
# Check Run 3 Number 80
#   Already aggregated, skip
# Check Run 3 Number 81
#   Already aggregated, skip
# Check Run 3 Number 82
#   Already aggregated, skip
# Check Run 3 Number 83
#   Already aggregated, skip
# Check Run 3 Number 84
#   Already aggregated, skip
# Check Run 3 Number 85
#   Already aggregated, skip
# Check Run 3 Number 86
#   Already aggregated, skip
# Check Run 3 Number 87
#   Already aggregated, skip
# Check Run 3 Number 88
#   Already aggregated, skip
# 14 elements in folder ../../results_all/app_history_influxdb\run3\89, skip.
# Check Run 3 Number 9
#   Already aggregated, skip
# 14 elements in folder ../../results_all/app_history_influxdb\run3\90, skip.
# 14 elements in folder ../../results_all/app_history_influxdb\run3\91, skip.
# 14 elements in folder ../../results_all/app_history_influxdb\run3\92, skip.
# 14 elements in folder ../../results_all/app_history_influxdb\run3\93, skip.
# 14 elements in folder ../../results_all/app_history_influxdb\run3\94, skip.
# Check Run 3 Number 95
#   Already aggregated, skip
# Check Run 3 Number 96
#   Already aggregated, skip
# Check Run 3 Number 97
#   Already aggregated, skip
# Check Run 3 Number 98
#   Already aggregated, skip
# Check Run 3 Number 99
#   Already aggregated, skip
